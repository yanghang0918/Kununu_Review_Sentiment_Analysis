# %%
import pandas as pd

# %%
#file_path = "/Users/alexanderprinz/Downloads/reviews.feather.featherï¼å¯æ¬ï¼"
file_path = "/Users/elenariegger/Desktop/Frankfurt School/3. Semester/SPM/reviews.feather.featherï¼å¯æ¬ï¼"
findata = pd.read_feather(file_path)
pd.set_option('display.max_columns', None)
print(findata.info())
print(findata.head(20))

reviews = findata
display(reviews)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257548 entries, 0 to 1257547
# Data columns (total 82 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   uuid                            1257548 non-null  object
#  1   type                            1257548 non-null  object
#  2   typeVersion                     1257548 non-null  object
#  3   source                          82282 non-null    object
#  4   title                           1244337 non-null  object
#  5   score                           1257548 non-null  float64
#  6   roundedScore                    1257548 non-null  float64
#  7   createdAt                       1257548 non-null  object
#  8   updatedAt                       1257548 non-null  object
#  9   company_id                      1257548 non-null  int64
#  10  company_uuid                    1257521 non-null  object
# ...

# %%
reviews = reviews.iloc[:20000,:]
reviews.to_csv('reviews.csv', index=False)
